# %%
# Data retrieval example using Python 3 with json output. This example utilizes the urllib 
#   library and $allrecords, storing the entire query in memory before writing it to a file 
#   it is simpler however may crash if there is insufficient memory, especially with the largest datasets
#   when handling large amounts of data look at one of the code examples with streaming instead

import urllib.request
import json

# define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# define a query using parameters 
#select = "?$select=disasterNumber,declarationDate,declarationTitle,state"    # leave this parameter out if you want all fields
#filter = "&$filter=state%20ne%20%27FL%27"                                    # for purposes of example, exclude Florida
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # issue api call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Print the metadata object
    print(json.dumps(jsonData['metadata'], indent=3))

except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")

# define a query using parameters 
#select = "?$select=disasterNumber,declarationDate,declarationTitle,state"    # leave this parameter out if you want all fields
#filter = "&$filter=state%20ne%20%27FL%27"                                    # for purposes of example, exclude Florida
#orderby = "&$orderby=id"                                                     # order unimportant to me, so use id
#format = "&$format=json"    
#other = "&$allrecords=true&$metadata=off"                                    # return all records, suppress metadata

# location for where the query results are saved
#saveLocation = './out.json'

# issue api call
request = urllib.request.urlopen(baseUrl)
result = request.read()
    
# The data is already returned in a json format. There is no need to decode and load as a JSON object.
#   If you want to begin working with and manipulating the JSON, import the json library and load with
#   something like: jsonData = json.loads(result.decode())

# save to file: NOTE: this example saves all records to a variable, this is faster and works well for smaller querries, 
#   with the larger datasets, this can cause memory problems and lead to crashes
#with open(saveLocation, "w") as writefile:
   # writefile.write(str(result,'utf-8'))


# lets re-open the file and see if we got the number of records we expected
#with open(saveLocation, "r") as readfile:
   # try:
    #    my_data = json.load(readfile)
   #     print(str(len(my_data['DisasterDeclarationsSummaries'])) + " records in file")
  # except Exception as error:
   #     print(error)
   # except:
  #      print("Something went wrong, the records could not be counted")

# use the dumps() function to display only the metadata objecta
print(json.dumps(jsonData['metadata'], indent=3))
# Out:
# {
#    "skip": 0,
#    "filter": "",
#    "orderby": "id ASC",
#    "select": null,
#    "rundate": "2024-12-23T05:22:37.006Z",
#    "top": 1000,
#    "format": "json",
#    "metadata": true,
#    "entityname": "IpawsArchivedAlerts",
#    "version": "v1",
#    "url": "/api/open/v1/IpawsArchivedAlerts?$orderby=id&$format=json",
#    "count": 0
# }
# {
#    "skip": 0,
#    "filter": "",
#    "orderby": "id ASC",
#    "select": null,
#    "rundate": "2024-12-23T05:22:37.006Z",
#    "top": 1000,
#    "format": "json",
#    "metadata": true,
#    "entityname": "IpawsArchivedAlerts",
#    "version": "v1",
#    "url": "/api/open/v1/IpawsArchivedAlerts?$orderby=id&$format=json",
#    "count": 0
# }

# %%
import urllib.request
import json
import xml.etree.ElementTree as ET

# define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# define a query using parameters 
#select = "?$select=disasterNumber,declarationDate,declarationTitle,state"    # leave this parameter out if you want all fields
#filter = "&$filter=state%20ne%20%27FL%27"                                    # for purposes of example, exclude Florida
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # issue api call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Extract the first record's "originalMessage" field
    originalMessage = jsonData['IpawsArchivedAlerts'][0]['originalMessage']
    
    # Parse the XML content
    root = ET.fromstring(originalMessage)
    
    # Extract specific elements (example: identifier, sender, sent date)
    identifier = root.find('identifier').text
    sender = root.find('sender').text
    sent = root.find('sent').text
    event = root.find('event').text
    description = root.find('description').text
    coordinates = root.find('coordinates')
    
    print(f"Identifier: {identifier}")
    print(f"Sender: {sender}")
    print(f"Sent: {sent}")
    print(f"Event: {event}")
    print(f"Description: {description}")
    print(f"Coordinates: {coordinates}")
    
    
    
except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")
except KeyError as e:
    print(f"KeyError: Missing key {e}")

# %%
# display the first record in the dataset object in a pretty format
print(json.dumps(jsonData['IpawsArchivedAlerts'][0:10], indent=2))
# Out:
# [
#   {
#     "originalMessage": "<alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-IDP-PROD-4445954-3699490</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2020-09-15T20:03:00-04:00</sent><status>Actual</status><msgType>Update</msgType><scope>Public</scope><code>IPAWSv1.0</code><note></note><references>w-nws.webmaster@noaa.gov,NWS-IDP-PROD-4445309-3698963,2020-09-15T09:59:00-04:00 w-nws.webmaster@noaa.gov,NWS-IDP-PROD-4445555-3699193,2020-09-15T14:03:00-04:00</references><info><language>en-US</language><category>Met</category><event>Coastal Flood Advisory</event><responseType>Monitor</responseType><urgency>Expected</urgency><severity>Minor</severity><certainty>Likely</certainty><eventCode><valueName>SAME</valueName><value>NWS</value></eventCode><eventCode><valueName>NationalWeatherService</valueName><value>CFY</value></eventCode><effective>2020-09-15T20:03:00-04:00</effective><onset>2020-09-15T20:03:00-04:00</onset><expires>2020-09-17T18:00:00-04:00</expires><senderName>NWS Tampa Bay Ruskin FL</senderName><headline>Coastal Flood Advisory issued September 15 at 8:03PM EDT until September 17 at 6:00PM EDT by NWS Tampa Bay Ruskin FL</headline><description>* COASTAL FLOODING...A combination of abnormally high tides and\nsurge from Sally will allow water levels to run 2 to 3 feet\nAbove Ground Level (3.5 to 4.5 feet MSL) during times of high\ntide through Thursday.\n\n* COASTAL FLOOD TIMING...During afternoon high tides through\nThursday.\n\n* COASTAL FLOOD IMPACTS...Minor coastal flooding, especially low-\nlying roads or other areas sensitive to nuisance flooding.</description><instruction>A Coastal Flood Advisory indicates that onshore winds and tides\nwill combine to generate flooding of low areas along the shore.</instruction><web>http://www.weather.gov</web><parameter><valueName>NWSheadline</valueName><value>COASTAL FLOOD ADVISORY REMAINS IN EFFECT UNTIL 6 PM EDT THURSDAY</value></parameter><parameter><valueName>VTEC</valueName><value>/O.CON.KTBW.CF.Y.0002.000000T0000Z-200917T2200Z/</value></parameter><parameter><valueName>PIL</valueName><value>TBWCFWTBW</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><parameter><valueName>eventEndingTime</valueName><value>2020-09-17T18:00:00-04:00</value></parameter><area><areaDesc>Coastal Citrus; Coastal Levy</areaDesc><geocode><valueName>UGC</valueName><value>FLZ142</value></geocode><geocode><valueName>UGC</valueName><value>FLZ139</value></geocode><geocode><valueName>SAME</valueName><value>012017</value></geocode><geocode><valueName>SAME</valueName><value>012075</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\" xmlns:wsa=\"http://www.w3.org/2005/08/addressing\" xmlns:env=\"http://schemas.xmlsoap.org/soap/envelope/\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>2wJpoeWLGXip3gtOK0uw3BozKhC3E9orHOR8DvUCqeI=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN200032,OU=A01410C0000016FECA3CC6E0000D10E,OU=Devices IPAWS,OU=National Continuity Programs,O=FEMA IPAWS,C=US</X509SubjectName><X509Certificate> ...
#     "identifier": "NWS-IDP-PROD-4445954-3699490",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2020-09-16T00:03:00.000Z",
#     "status": "Actual",
#     "msgType": "Update",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": "",
#     "searchGeometry": null,
#     "incidents": null,
#     "cogId": 200032,
#     "id": "00000225-230a-4c98-acbf-9c9eccdface5",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 359005,
#                 "name": "UGC",
#                 "value": "FLZ142"
#               },
#               {
#                 "id": 358785,
#                 "name": "UGC",
#                 "value": "FLZ139"
#               },
#               {
#                 "id": 50,
#                 "name": "SAME",
#                 "value": "012017"
#               },
#               {
#                 "id": 462,
#                 "name": "SAME",
#                 "value": "012075"
#               }
#             ],
#             "areaDesc": "Coastal Citrus; Coastal Levy"
#           }
#         ],
#         "event": "Coastal Flood Advisory",
#         "onset": "2020-09-15T20:03:00-04:00",
#         "expires": "2020-09-17T18:00:00-04:00",
#         "urgency": "Expected",
#         "category": [
#           "Met"
#         ],
#         "headline": "Coastal Flood Advisory issued September 15 at 8:03PM EDT until September 17 at 6:00PM EDT by NWS Tampa Bay Ruskin FL",
#         "language": "en-US",
#         "severity": "Minor",
#         "certainty": "Likely",
#         "effective": "2020-09-15T20:03:00-04:00",
#         "eventCode": [
#           {
#             "id": 1582,
#             "name": "SAME",
#             "value": "NWS"
#           },
#           {
#             "id": 1606,
#             "name": "NationalWeatherService",
#             "value": "CFY"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "NWSheadline",
#             "value": "COASTAL FLOOD ADVISORY REMAINS IN EFFECT UNTIL 6 PM EDT THURSDAY"
#           },
#           {
#             "name": "VTEC",
#             "value": "/O.CON.KTBW.CF.Y.0002.000000T0000Z-200917T2200Z/"
#           },
#           {
#             "name": "PIL",
#             "value": "TBWCFWTBW"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           },
#           {
#             "name": "eventEndingTime",
#             "value": "2020-09-17T18:00:00-04:00"
#           }
#         ],
#         "senderName": "NWS Tampa Bay Ruskin FL",
#         "description": "* COASTAL FLOODING...A combination of abnormally high tides and\nsurge from Sally will allow water levels to run 2 to 3 feet\nAbove Ground Level (3.5 to 4.5 feet MSL) during times of high\ntide through Thursday.\n\n* COASTAL FLOOD TIMING...During afternoon high tides through\nThursday.\n\n* COASTAL FLOOD IMPACTS...Minor coastal flooding, especially low-\nlying roads or other areas sensitive to nuisance flooding.",
#         "instruction": "A Coastal Flood Advisory indicates that onshore winds and tides\nwill combine to generate flooding of low areas along the shore.",
#         "responseType": [
#           "Monitor"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-IDP-PROD-4767760-3849910</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2021-02-06T14:12:00-05:00</sent><status>Actual</status><msgType>Update</msgType><scope>Public</scope><code>IPAWSv1.0</code><note></note><references>w-nws.webmaster@noaa.gov,NWS-IDP-PROD-4766455-3849262,2021-02-06T04:00:00-05:00 w-nws.webmaster@noaa.gov,NWS-IDP-PROD-4767257-3849666,2021-02-06T10:04:00-05:00</references><info><language>en-US</language><category>Met</category><event>Small Craft Advisory</event><responseType>Avoid</responseType><urgency>Expected</urgency><severity>Minor</severity><certainty>Likely</certainty><eventCode><valueName>SAME</valueName><value>NWS</value></eventCode><eventCode><valueName>NationalWeatherService</valueName><value>SCY</value></eventCode><effective>2021-02-06T14:12:00-05:00</effective><onset>2021-02-07T04:00:00-05:00</onset><expires>2021-02-07T04:30:00-05:00</expires><senderName>NWS Wakefield VA</senderName><headline>Small Craft Advisory issued February 6 at 2:12PM EST until February 7 at 4:00PM EST by NWS Wakefield VA</headline><description>* WHAT...North winds 15 to 20 kt with gusts up to 25 kt and\nwaves around 2 ft expected.\n\n* WHERE...Currituck Sound.\n\n* WHEN...From 4 AM to 4 PM EST Sunday.\n\n* IMPACTS...Conditions will be hazardous to small craft.</description><instruction>Inexperienced mariners, especially those operating smaller\nvessels, should avoid navigating in hazardous conditions.</instruction><web>http://www.weather.gov</web><parameter><valueName>NWSheadline</valueName><value>SMALL CRAFT ADVISORY REMAINS IN EFFECT FROM 4 AM TO 4 PM EST SUNDAY</value></parameter><parameter><valueName>VTEC</valueName><value>/O.CON.KAKQ.SC.Y.0015.210207T0900Z-210207T2100Z/</value></parameter><parameter><valueName>PIL</valueName><value>AKQMWWAKQ</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><parameter><valueName>eventEndingTime</valueName><value>2021-02-07T16:00:00-05:00</value></parameter><area><areaDesc>Currituck Sound</areaDesc><geocode><valueName>UGC</valueName><value>ANZ633</value></geocode><geocode><valueName>SAME</valueName><value>073633</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\" xmlns:wsa=\"http://www.w3.org/2005/08/addressing\" xmlns:env=\"http://schemas.xmlsoap.org/soap/envelope/\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>5V5JgpXqNmSBGEd5wjDvj93pZmPzThCjSx/YUfRJjuk=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN200032,OU=A01410C0000016FECA3CC6E0000D10E,OU=Devices IPAWS,OU=National Continuity Programs,O=FEMA IPAWS,C=US</X509SubjectName><X509Certificate> ...
#     "identifier": "NWS-IDP-PROD-4767760-3849910",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2021-02-06T19:12:00.000Z",
#     "status": "Actual",
#     "msgType": "Update",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": "",
#     "searchGeometry": null,
#     "incidents": null,
#     "cogId": 200032,
#     "id": "0000090c-2abb-44f1-affb-20d94b382605",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 391287,
#                 "name": "UGC",
#                 "value": "ANZ633"
#               },
#               {
#                 "id": 391503,
#                 "name": "SAME",
#                 "value": "073633"
#               }
#             ],
#             "areaDesc": "Currituck Sound"
#           }
#         ],
#         "event": "Small Craft Advisory",
#         "onset": "2021-02-07T04:00:00-05:00",
#         "expires": "2021-02-07T04:30:00-05:00",
#         "urgency": "Expected",
#         "category": [
#           "Met"
#         ],
#         "headline": "Small Craft Advisory issued February 6 at 2:12PM EST until February 7 at 4:00PM EST by NWS Wakefield VA",
#         "language": "en-US",
#         "severity": "Minor",
#         "certainty": "Likely",
#         "effective": "2021-02-06T14:12:00-05:00",
#         "eventCode": [
#           {
#             "id": 1582,
#             "name": "SAME",
#             "value": "NWS"
#           },
#           {
#             "id": 1589,
#             "name": "NationalWeatherService",
#             "value": "SCY"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "NWSheadline",
#             "value": "SMALL CRAFT ADVISORY REMAINS IN EFFECT FROM 4 AM TO 4 PM EST SUNDAY"
#           },
#           {
#             "name": "VTEC",
#             "value": "/O.CON.KAKQ.SC.Y.0015.210207T0900Z-210207T2100Z/"
#           },
#           {
#             "name": "PIL",
#             "value": "AKQMWWAKQ"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           },
#           {
#             "name": "eventEndingTime",
#             "value": "2021-02-07T16:00:00-05:00"
#           }
#         ],
#         "senderName": "NWS Wakefield VA",
#         "description": "* WHAT...North winds 15 to 20 kt with gusts up to 25 kt and\nwaves around 2 ft expected.\n\n* WHERE...Currituck Sound.\n\n* WHEN...From 4 AM to 4 PM EST Sunday.\n\n* IMPACTS...Conditions will be hazardous to small craft.",
#         "instruction": "Inexperienced mariners, especially those operating smaller\nvessels, should avoid navigating in hazardous conditions.",
#         "responseType": [
#           "Avoid"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"yes\"?><alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-141029-1252843-1199419</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2016-04-15T22:02:08-05:00</sent><status>Actual</status><msgType>Alert</msgType><scope>Public</scope><code>IPAWSv1.0</code><info><category>Met</category><event>Severe Thunderstorm Warning</event><responseType>Shelter</responseType><urgency>Immediate</urgency><severity>Severe</severity><certainty>Observed</certainty><eventCode><valueName>SAME</valueName><value>SVR</value></eventCode><effective>2016-04-15T22:02:08-05:00</effective><onset>2016-04-15T22:02:00-05:00</onset><expires>2016-04-15T22:45:00-05:00</expires><senderName>NWS Dodge City KS</senderName><headline>Severe Thunderstorm Warning issued April 15 at 10:02PM CDT expiring April 15 at 10:45PM CDT by NWS Dodge City KS</headline><description>THE NATIONAL WEATHER SERVICE IN DODGE CITY HAS ISSUED A\n\n* SEVERE THUNDERSTORM WARNING FOR...\n  SOUTHEASTERN HAMILTON COUNTY IN SOUTHWESTERN KANSAS...\n  NORTHEASTERN STANTON COUNTY IN SOUTHWESTERN KANSAS...\n  SOUTHWESTERN KEARNY COUNTY IN SOUTHWESTERN KANSAS...\n  NORTHERN GRANT COUNTY IN SOUTHWESTERN KANSAS...\n\n* UNTIL 1045 PM CDT/945 PM MDT/\n\n* AT 1001 PM CDT/901 PM MDT/...A SEVERE THUNDERSTORM WAS LOCATED VERY\n  NEAR JOHNSON CITY...MOVING NORTHEAST AT 25 MPH.\n\n  HAZARD...QUARTER SIZE HAIL. \n\n  SOURCE...RADAR INDICATED. \n\n  IMPACT...DAMAGE TO VEHICLES IS EXPECTED. \n\n* LOCATIONS IMPACTED INCLUDE...\n  JOHNSON CITY AND BIG BOW.</description><instruction>TO REPORT SEVERE WEATHER CONTACT YOUR NEAREST LAW ENFORCEMENT AGENCY.\nTHEY WILL SEND YOUR REPORT TO THE NATIONAL WEATHER SERVICE OFFICE IN\nDODGE CITY.\n\nFOR YOUR PROTECTION MOVE TO AN INTERIOR ROOM ON THE LOWEST FLOOR OF A\nBUILDING.\n\n</instruction><web>http://www.weather.gov</web><parameter><valueName>VTEC</valueName><value>/O.NEW.KDDC.SV.W.0007.160416T0302Z-160416T0345Z/</value></parameter><parameter><valueName>EAS-ORG</valueName><value>WXR</value></parameter><parameter><valueName>PIL</valueName><value>DDCSVRDDC</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><parameter><valueName>eventEndingTime</valueName><value>2016-04-15T22:45:00-05:00</value></parameter><area><areaDesc>Stanton; Hamilton; Grant; Kearny</areaDesc><polygon>37.5,-101.69 37.72,-101.87 37.92,-101.36 37.68,-101.16 37.5,-101.69</polygon><geocode><valueName>UGC</valueName><value>KSC067</value></geocode><geocode><valueName>UGC</valueName><value>KSC093</value></geocode><geocode><valueName>UGC</valueName><value>KSC075</value></geocode><geocode><valueName>UGC</valueName><value>KSC187</value></geocode><geocode><valueName>SAME</valueName><value>020187</value></geocode><geocode><valueName>SAME</valueName><value>020075</value></geocode><geocode><valueName>SAME</valueName><value>020067</value></geocode><geocode><valueName>SAME</valueName><value>020093</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>urGgg9rTHgndM3DMFbB71/dzoKf3frROVco0F0fRogo=</DigestValue></Reference></SignedInfo><SignatureValue>C03aOIwR3+D6Hk6cPOD/o8opb98UTksjU989hJef4ON+MaNMGOT4+C/R/SWtI7BNx36/NO3/xzXT\nR1Og0MpxOCVE7629EjFSfJZXFVocJ18U/k6U8g/M2pp5h8lEItf5YJTO34pyz9DWznfON8JrXCry\naSG/oPnInS2YowuVE9yusaxRiwfxq+57eKoadtRbfpxWGfJyereLP2mHEfpgHRnUm8LAJPqzrkb3\nmPUpmkA+/NPOd2GRd7+XVoBjyMs3Ug918KF6cEHIpvGT ...
#     "identifier": "NWS-141029-1252843-1199419",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2016-04-16T03:02:08.000Z",
#     "status": "Actual",
#     "msgType": "Alert",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": null,
#     "searchGeometry": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -101.69,
#             37.5
#           ],
#           [
#             -101.16,
#             37.68
#           ],
#           [
#             -101.36,
#             37.92
#           ],
#           [
#             -101.87,
#             37.72
#           ],
#           [
#             -101.69,
#             37.5
#           ]
#         ]
#       ]
#     },
#     "incidents": null,
#     "cogId": 200032,
#     "id": "00000ceb-1911-4dd3-9440-382393a553da",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 7977,
#                 "name": "UGC",
#                 "value": "KSC067"
#               },
#               {
#                 "id": 9231,
#                 "name": "UGC",
#                 "value": "KSC093"
#               },
#               {
#                 "id": 688,
#                 "name": "UGC",
#                 "value": "KSC075"
#               },
#               {
#                 "id": 4108,
#                 "name": "UGC",
#                 "value": "KSC187"
#               },
#               {
#                 "id": 4251,
#                 "name": "SAME",
#                 "value": "020187"
#               },
#               {
#                 "id": 737,
#                 "name": "SAME",
#                 "value": "020075"
#               },
#               {
#                 "id": 8168,
#                 "name": "SAME",
#                 "value": "020067"
#               },
#               {
#                 "id": 4350,
#                 "name": "SAME",
#                 "value": "020093"
#               }
#             ],
#             "polygon": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -101.69,
#                     37.5
#                   ],
#                   [
#                     -101.87,
#                     37.72
#                   ],
#                   [
#                     -101.36,
#                     37.92
#                   ],
#                   [
#                     -101.16,
#                     37.68
#                   ],
#                   [
#                     -101.69,
#                     37.5
#                   ]
#                 ]
#               ]
#             },
#             "areaDesc": "Stanton; Hamilton; Grant; Kearny"
#           }
#         ],
#         "event": "Severe Thunderstorm Warning",
#         "onset": "2016-04-15T22:02:00-05:00",
#         "expires": "2016-04-15T22:45:00-05:00",
#         "urgency": "Immediate",
#         "category": [
#           "Met"
#         ],
#         "headline": "Severe Thunderstorm Warning issued April 15 at 10:02PM CDT expiring April 15 at 10:45PM CDT by NWS Dodge City KS",
#         "severity": "Severe",
#         "certainty": "Observed",
#         "effective": "2016-04-15T22:02:08-05:00",
#         "eventCode": [
#           {
#             "id": 14,
#             "name": "SAME",
#             "value": "SVR"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "VTEC",
#             "value": "/O.NEW.KDDC.SV.W.0007.160416T0302Z-160416T0345Z/"
#           },
#           {
#             "name": "EAS-ORG",
#             "value": "WXR"
#           },
#           {
#             "name": "PIL",
#             "value": "DDCSVRDDC"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           },
#           {
#             "name": "eventEndingTime",
#             "value": "2016-04-15T22:45:00-05:00"
#           }
#         ],
#         "senderName": "NWS Dodge City KS",
#         "description": "THE NATIONAL WEATHER SERVICE IN DODGE CITY HAS ISSUED A\n\n* SEVERE THUNDERSTORM WARNING FOR...\n  SOUTHEASTERN HAMILTON COUNTY IN SOUTHWESTERN KANSAS...\n  NORTHEASTERN STANTON COUNTY IN SOUTHWESTERN KANSAS...\n  SOUTHWESTERN KEARNY COUNTY IN SOUTHWESTERN KANSAS...\n  NORTHERN GRANT COUNTY IN SOUTHWESTERN KANSAS...\n\n* UNTIL 1045 PM CDT/945 PM MDT/\n\n* AT 1001 PM CDT/901 PM MDT/...A SEVERE THUNDERSTORM WAS LOCATED VERY\n  NEAR JOHNSON CITY...MOVING NORTHEAST AT 25 MPH.\n\n  HAZARD...QUARTER SIZE HAIL. \n\n  SOURCE...RADAR INDICATED. \n\n  IMPACT...DAMAGE TO VEHICLES IS EXPECTED. \n\n* LOCATIONS IMPACTED INCLUDE...\n  JOHNSON CITY AND BIG BOW.",
#         "instruction": "TO REPORT SEVERE WEATHER CONTACT YOUR NEAREST LAW ENFORCEMENT AGENCY.\nTHEY WILL SEND YOUR REPORT TO THE NATIONAL WEATHER SERVICE OFFICE IN\nDODGE CITY.\n\nFOR YOUR PROTECTION MOVE TO AN INTERIOR ROOM ON THE LOWEST FLOOR OF A\nBUILDING.\n\n",
#         "responseType": [
#           "Shelter"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"yes\"?><alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-IDP-PROD-3927867</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2019-11-26T05:24:00-09:00</sent><status>Actual</status><msgType>Alert</msgType><scope>Public</scope><code>IPAWSv1.0</code><note></note><info><language>en-US</language><category>Met</category><event>Special Weather Statement</event><responseType>Execute</responseType><urgency>Expected</urgency><severity>Moderate</severity><certainty>Observed</certainty><eventCode><valueName>SAME</valueName><value>SPS</value></eventCode><eventCode><valueName>NationalWeatherService</valueName><value>SPS</value></eventCode><effective>2019-11-26T05:24:00-09:00</effective><onset>2019-11-26T05:24:00-09:00</onset><expires>2019-11-26T12:00:00-09:00</expires><senderName>NWS Anchorage, AK</senderName><headline>Special Weather Statement issued November 26 at 5:24AM AKST by NWS Anchorage, AK</headline><description>Snow is expected to develop on Wednesday morning over the eastern\nKenai Peninsula and become heavier by afternoon. Easterly winds\nthrough Turnagain Arm are also expected to increase on Wednesday\nand bring the potential for periods of reduced visibility along\nthe highway due to blowing snow. Warmer air moving into the\nregion will start to turn the snow to rain in Seward and Turnagain\nArm Wednesday night and continue as rain into Thursday in those\nlocations.\n\nFor Turnagain Pass, precipitation is likely to remain snow\nthrough Thursday with periods of reduced visibility in blowing\nsnow.\n\nStay tuned to the latest forecasts at weather.gov/Anchorage.</description><web>http://www.weather.gov</web><parameter><valueName>NWSheadline</valueName><value>Snow on Wednesday turning to a wintery mix by Thursday</value></parameter><parameter><valueName>EAS-ORG</valueName><value>WXR</value></parameter><parameter><valueName>PIL</valueName><value>AERSPSAER</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><area><areaDesc>Western Prince William Sound</areaDesc><geocode><valueName>UGC</valueName><value>AKZ125</value></geocode><geocode><valueName>SAME</valueName><value>002261</value></geocode><geocode><valueName>SAME</valueName><value>002122</value></geocode><geocode><valueName>SAME</valueName><value>002020</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>Kgu0OYqJB2OKiHA4gCLndzd4qgOJhqLI7Mo1HlhAy7w=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN_200032,OU=7F0000010000015ACCFEADCE0000106B,OU=Devices IPAWS,OU=National Continuity Programs,O=FEMA IPAWS,C=US</X509SubjectName><X509Certificate>\nbCBDb250aW51aXR5I ...
#     "identifier": "NWS-IDP-PROD-3927867",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2019-11-26T14:24:00.000Z",
#     "status": "Actual",
#     "msgType": "Alert",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": "",
#     "searchGeometry": null,
#     "incidents": null,
#     "cogId": 200032,
#     "id": "00000cf8-82e7-4c90-8459-bb1efc8c372f",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 461515,
#                 "name": "UGC",
#                 "value": "AKZ125"
#               },
#               {
#                 "id": 9666,
#                 "name": "SAME",
#                 "value": "002261"
#               },
#               {
#                 "id": 309684,
#                 "name": "SAME",
#                 "value": "002122"
#               },
#               {
#                 "id": 431495,
#                 "name": "SAME",
#                 "value": "002020"
#               }
#             ],
#             "areaDesc": "Western Prince William Sound"
#           }
#         ],
#         "event": "Special Weather Statement",
#         "onset": "2019-11-26T05:24:00-09:00",
#         "expires": "2019-11-26T12:00:00-09:00",
#         "urgency": "Expected",
#         "category": [
#           "Met"
#         ],
#         "headline": "Special Weather Statement issued November 26 at 5:24AM AKST by NWS Anchorage, AK",
#         "language": "en-US",
#         "severity": "Moderate",
#         "certainty": "Observed",
#         "effective": "2019-11-26T05:24:00-09:00",
#         "eventCode": [
#           {
#             "id": 6,
#             "name": "SAME",
#             "value": "SPS"
#           },
#           {
#             "id": 1581,
#             "name": "NationalWeatherService",
#             "value": "SPS"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "NWSheadline",
#             "value": "Snow on Wednesday turning to a wintery mix by Thursday"
#           },
#           {
#             "name": "EAS-ORG",
#             "value": "WXR"
#           },
#           {
#             "name": "PIL",
#             "value": "AERSPSAER"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           }
#         ],
#         "senderName": "NWS Anchorage, AK",
#         "description": "Snow is expected to develop on Wednesday morning over the eastern\nKenai Peninsula and become heavier by afternoon. Easterly winds\nthrough Turnagain Arm are also expected to increase on Wednesday\nand bring the potential for periods of reduced visibility along\nthe highway due to blowing snow. Warmer air moving into the\nregion will start to turn the snow to rain in Seward and Turnagain\nArm Wednesday night and continue as rain into Thursday in those\nlocations.\n\nFor Turnagain Pass, precipitation is likely to remain snow\nthrough Thursday with periods of reduced visibility in blowing\nsnow.\n\nStay tuned to the latest forecasts at weather.gov/Anchorage.",
#         "responseType": [
#           "Execute"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>urn:oid:2.49.0.1.840.0.15e3aa787d8309418977a87815a01da8bbef682c.001.1</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2022-04-16T01:48:00-05:00</sent><status>Actual</status><msgType>Cancel</msgType><scope>Public</scope><code>IPAWSv1.0</code><references>w-nws.webmaster@noaa.gov,urn:oid:2.49.0.1.840.0.61edd36818eafb168cc1c17a90d9da699b1cf65e.001.1,2022-04-16T00:55:00-05:00</references><info><language>en-US</language><category>Met</category><event>Severe Thunderstorm Warning</event><responseType>AllClear</responseType><urgency>Past</urgency><severity>Minor</severity><certainty>Observed</certainty><eventCode><valueName>SAME</valueName><value>SVS</value></eventCode><eventCode><valueName>NationalWeatherService</valueName><value>SVW</value></eventCode><effective>2022-04-16T01:48:00-05:00</effective><onset>2022-04-16T01:48:00-05:00</onset><expires>2022-04-16T02:03:26-05:00</expires><senderName>NWS Tulsa OK</senderName><headline>The Severe Thunderstorm Warning has been cancelled.</headline><description>The Severe Thunderstorm Warning has been cancelled and is no longer in effect.</description><web>http://www.weather.gov</web><parameter><valueName>AWIPSidentifier</valueName><value>SVSTSA</value></parameter><parameter><valueName>WMOidentifier</valueName><value>WWUS54 KTSA 160648</value></parameter><parameter><valueName>NWSheadline</valueName><value>THE SEVERE THUNDERSTORM WARNING FOR SOUTHERN OKMULGEE COUNTY IS CANCELLED</value></parameter><parameter><valueName>eventMotionDescription</valueName><value>2022-04-16T06:47:00Z...storm...272DEG...21KT...35.53,-95.62</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><parameter><valueName>EAS-ORG</valueName><value>WXR</value></parameter><parameter><valueName>VTEC</valueName><value>/O.CAN.KTSA.SV.W.0059.000000T0000Z-220416T0700Z/</value></parameter><parameter><valueName>eventEndingTime</valueName><value>2022-04-16T02:00:00-05:00</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>expiredReferences</valueName><value>w-nws.webmaster@noaa.gov,urn:oid:2.49.0.1.840.0.875c2ed3a08629bb824eea1de0ae7d9990ebe555.001.1,2021-04-28T21:06:00-05:00</value></parameter><area><areaDesc>Okmulgee, OK</areaDesc><polygon>35.55,-95.71 35.59,-95.71 35.6,-95.51 35.55,-95.52 35.4,-95.49 35.48,-95.73 35.55,-95.76 35.55,-95.71</polygon><geocode><valueName>SAME</valueName><value>040111</value></geocode><geocode><valueName>UGC</valueName><value>OKC111</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\" xmlns:ns5=\"http://gov.fema.ipaws.services/IPAWS_CAPService/\" xmlns:ns2=\"urn:oasis:names:tc:emergency:cap:1.2\" xmlns:ns4=\"http://gov.fema.ipaws.services/capresponse\" xmlns:ns3=\"http://gov.fema.ipaws.services/caprequest\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>jPf45WfyxudL8hixDIRzsF663MgNqWc/jpqw2W0wq1A=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN200032,OU=A01410C0000016FECA3CC6E0000D10E,OU=Devices IPAWS,OU=National Continuity Programs,O=FEMA IPAWS,C= ...
#     "identifier": "urn:oid:2.49.0.1.840.0.15e3aa787d8309418977a87815a01da8bbef682c.001.1",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2022-04-16T06:48:00.000Z",
#     "status": "Actual",
#     "msgType": "Cancel",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": null,
#     "searchGeometry": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -95.71,
#             35.55
#           ],
#           [
#             -95.76,
#             35.55
#           ],
#           [
#             -95.73,
#             35.48
#           ],
#           [
#             -95.49,
#             35.4
#           ],
#           [
#             -95.52,
#             35.55
#           ],
#           [
#             -95.51,
#             35.6
#           ],
#           [
#             -95.71,
#             35.59
#           ],
#           [
#             -95.71,
#             35.55
#           ]
#         ]
#       ]
#     },
#     "incidents": null,
#     "cogId": 200032,
#     "id": "000014f1-65d5-4ba4-898d-967497f07a57",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 18599,
#                 "name": "SAME",
#                 "value": "040111"
#               },
#               {
#                 "id": 18226,
#                 "name": "UGC",
#                 "value": "OKC111"
#               }
#             ],
#             "polygon": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -95.71,
#                     35.55
#                   ],
#                   [
#                     -95.71,
#                     35.59
#                   ],
#                   [
#                     -95.51,
#                     35.6
#                   ],
#                   [
#                     -95.52,
#                     35.55
#                   ],
#                   [
#                     -95.49,
#                     35.4
#                   ],
#                   [
#                     -95.73,
#                     35.48
#                   ],
#                   [
#                     -95.76,
#                     35.55
#                   ],
#                   [
#                     -95.71,
#                     35.55
#                   ]
#                 ]
#               ]
#             },
#             "areaDesc": "Okmulgee, OK"
#           }
#         ],
#         "event": "Severe Thunderstorm Warning",
#         "onset": "2022-04-16T01:48:00-05:00",
#         "expires": "2022-04-16T02:03:26-05:00",
#         "urgency": "Past",
#         "category": [
#           "Met"
#         ],
#         "headline": "The Severe Thunderstorm Warning has been cancelled.",
#         "language": "en-US",
#         "severity": "Minor",
#         "certainty": "Observed",
#         "effective": "2022-04-16T01:48:00-05:00",
#         "eventCode": [
#           {
#             "id": 7,
#             "name": "SAME",
#             "value": "SVS"
#           },
#           {
#             "id": 1587,
#             "name": "NationalWeatherService",
#             "value": "SVW"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "AWIPSidentifier",
#             "value": "SVSTSA"
#           },
#           {
#             "name": "WMOidentifier",
#             "value": "WWUS54 KTSA 160648"
#           },
#           {
#             "name": "NWSheadline",
#             "value": "THE SEVERE THUNDERSTORM WARNING FOR SOUTHERN OKMULGEE COUNTY IS CANCELLED"
#           },
#           {
#             "name": "eventMotionDescription",
#             "value": "2022-04-16T06:47:00Z...storm...272DEG...21KT...35.53,-95.62"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           },
#           {
#             "name": "EAS-ORG",
#             "value": "WXR"
#           },
#           {
#             "name": "VTEC",
#             "value": "/O.CAN.KTSA.SV.W.0059.000000T0000Z-220416T0700Z/"
#           },
#           {
#             "name": "eventEndingTime",
#             "value": "2022-04-16T02:00:00-05:00"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "expiredReferences",
#             "value": "w-nws.webmaster@noaa.gov,urn:oid:2.49.0.1.840.0.875c2ed3a08629bb824eea1de0ae7d9990ebe555.001.1,2021-04-28T21:06:00-05:00"
#           }
#         ],
#         "senderName": "NWS Tulsa OK",
#         "description": "The Severe Thunderstorm Warning has been cancelled and is no longer in effect.",
#         "responseType": [
#           "AllClear"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"yes\"?><alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-IDP-PROD-2775732-2588301</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2018-04-16T20:26:18-05:00</sent><status>Actual</status><msgType>Update</msgType><scope>Public</scope><code>IPAWSv1.0</code><note></note><references>w-nws.webmaster@noaa.gov,NWS-IDP-PROD-2774483-2587325,2018-04-16T10:07:16-05:00</references><info><category>Met</category><event>Flood Advisory</event><responseType>Avoid</responseType><urgency>Expected</urgency><severity>Minor</severity><certainty>Observed</certainty><eventCode><valueName>SAME</valueName><value>NWS</value></eventCode><eventCode><valueName>NationalWeatherService</valueName><value>FLY</value></eventCode><effective>2018-04-16T20:26:18-05:00</effective><onset>2018-04-16T20:26:00-05:00</onset><expires>2018-04-17T08:24:00-05:00</expires><senderName>NWS Chicago IL</senderName><headline>Flood Advisory issued April 16 at 8:26PM CDT expiring April 20 at 7:01PM CDT by NWS Chicago IL</headline><description>Kankakee River at Dunns Bridge affecting Porter County\nKankakee River near Kouts affecting Jasper and Porter Counties\nThe Flood Advisory continues for\nThe Kankakee River near Kouts\n* until Friday evening.\n* At  800 PM Monday the stage was 8.7 feet.\n* Action stage is 10.5 feet.\n* Flood stage is 11.0 feet.\n* Forecast...The river will rise to near 10.6 feet by early Thursday\nmorning.\n* Impact...At 11.0 feet...Agricultural areas begin to flood. Some\nbackwaters begin to fill drainage ditches.\n</description><instruction>PRECAUTIONARY/PREPAREDNESS ACTIONS...\n\nSafety message...If you encounter a flooded roadway...turn around and\nfind an alternate route.\n\nAdditional information can be found at weather.gov/chicago.\n\n</instruction><web>http://www.weather.gov</web><parameter><valueName>VTEC</valueName><value>/O.CON.KLOT.FL.Y.0032.000000T0000Z-180421T0001Z/</value></parameter><parameter><valueName>PIL</valueName><value>LOTFLSLOT</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><parameter><valueName>eventEndingTime</valueName><value>2018-04-20T19:01:00-05:00</value></parameter><area><areaDesc>Jasper, IN; Porter, IN</areaDesc><polygon>41.22,-87.06 41.22,-87.11 41.18,-87.23 41.27,-87.27 41.32,-87.13 41.28,-87 41.22,-87.06</polygon><geocode><valueName>UGC</valueName><value>INC073</value></geocode><geocode><valueName>UGC</valueName><value>INC127</value></geocode><geocode><valueName>SAME</valueName><value>018073</value></geocode><geocode><valueName>SAME</valueName><value>018127</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>8jTnPfp9MDWJOVYJRSQfilCMNE9gnzMcAbMm4C88FYo=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN_200032,OU=7F0000010000015ACCFEADCE0000106B,OU=Devices IPAWS,OU=National Continuity Programs,O=FEMA IPAWS,C=US</X509SubjectName><X509Certificate>MIIGPTCCBSWgAwIBAgIQQAFazP6uAHAfg8+SGtXJFzANBgkqhkiG9w0BAQsF ...
#     "identifier": "NWS-IDP-PROD-2775732-2588301",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2018-04-17T01:26:18.000Z",
#     "status": "Actual",
#     "msgType": "Update",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": "",
#     "searchGeometry": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -87.06,
#             41.22
#           ],
#           [
#             -87,
#             41.28
#           ],
#           [
#             -87.13,
#             41.32
#           ],
#           [
#             -87.27,
#             41.27
#           ],
#           [
#             -87.23,
#             41.18
#           ],
#           [
#             -87.11,
#             41.22
#           ],
#           [
#             -87.06,
#             41.22
#           ]
#         ]
#       ]
#     },
#     "incidents": null,
#     "cogId": 200032,
#     "id": "00001baa-e9f1-4e04-ad8d-b17e94dddce4",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 54178,
#                 "name": "UGC",
#                 "value": "INC073"
#               },
#               {
#                 "id": 54266,
#                 "name": "UGC",
#                 "value": "INC127"
#               },
#               {
#                 "id": 54413,
#                 "name": "SAME",
#                 "value": "018073"
#               },
#               {
#                 "id": 54368,
#                 "name": "SAME",
#                 "value": "018127"
#               }
#             ],
#             "polygon": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -87.06,
#                     41.22
#                   ],
#                   [
#                     -87.11,
#                     41.22
#                   ],
#                   [
#                     -87.23,
#                     41.18
#                   ],
#                   [
#                     -87.27,
#                     41.27
#                   ],
#                   [
#                     -87.13,
#                     41.32
#                   ],
#                   [
#                     -87,
#                     41.28
#                   ],
#                   [
#                     -87.06,
#                     41.22
#                   ]
#                 ]
#               ]
#             },
#             "areaDesc": "Jasper, IN; Porter, IN"
#           }
#         ],
#         "event": "Flood Advisory",
#         "onset": "2018-04-16T20:26:00-05:00",
#         "expires": "2018-04-17T08:24:00-05:00",
#         "urgency": "Expected",
#         "category": [
#           "Met"
#         ],
#         "headline": "Flood Advisory issued April 16 at 8:26PM CDT expiring April 20 at 7:01PM CDT by NWS Chicago IL",
#         "severity": "Minor",
#         "certainty": "Observed",
#         "effective": "2018-04-16T20:26:18-05:00",
#         "eventCode": [
#           {
#             "id": 1582,
#             "name": "SAME",
#             "value": "NWS"
#           },
#           {
#             "id": 3935,
#             "name": "NationalWeatherService",
#             "value": "FLY"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "VTEC",
#             "value": "/O.CON.KLOT.FL.Y.0032.000000T0000Z-180421T0001Z/"
#           },
#           {
#             "name": "PIL",
#             "value": "LOTFLSLOT"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           },
#           {
#             "name": "eventEndingTime",
#             "value": "2018-04-20T19:01:00-05:00"
#           }
#         ],
#         "senderName": "NWS Chicago IL",
# ...
#         "instruction": "A Tornado Watch remains in effect until 800 PM CST for northeastern\nIllinois.\n\nFor your protection move to an interior room on the lowest floor of a\nbuilding.",
#         "responseType": [
#           "Shelter"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"yes\"?><alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-130404-607269</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2013-11-07T16:46:55-06:00</sent><status>Actual</status><msgType>Alert</msgType><scope>Public</scope><code>IPAWSv1.0</code><info><category>Met</category><event>Extreme Fire Danger</event><responseType>Prepare</responseType><urgency>Expected</urgency><severity>Moderate</severity><certainty>Likely</certainty><eventCode><valueName>SAME</valueName><value>OTH</value></eventCode><effective>2013-11-07T16:46:55-06:00</effective><onset>2013-11-07T16:46:00-06:00</onset><expires>2013-11-08T11:00:00-06:00</expires><senderName>NWS Wichita KS</senderName><headline>Extreme Fire Danger issued November 7 at 4:46PM CST by NWS Wichita KS</headline><description>THE GFDI DOES NOT ACCOUNT FOR PRECIPITATION THAT OCCURS WITHIN\nTHE HOUR PRECEDING ANY GIVEN FORECAST HOUR BELOW OR ANY SNOW ON\nTHE GROUND AT THE FORECAST HOUR. PLEASE MAKE APPROPRIATE ADJUSTMENTS.(ALL TIME REFERENCES ARE IN CST)\n\nDAY/DATE      24HR INDEX   *  MID  3AM  6AM  9AM NOON  3PM  6PM  9PM\nTHU NOV 07  LOW         0  *                                 L    L  \nFRI NOV 08  MODERATE    3  *   L    L    L    L    L    M    L    L  \nSAT NOV 09  LOW         1  *   L    L    L    L    L    L    L    L  \nSUN NOV 10  LOW         0  *   L    L    L    L    L    L    L    L  \nMON NOV 11  LOW         0  *   L    L    L    L    L    L    L    L  \nTUE NOV 12  LOW         0  *   L    L    L    L    L    L    L    L</description><instruction></instruction><web>http://www.weather.gov</web><parameter><valueName>PIL</valueName><value>ICTRFDICT</value></parameter><area><areaDesc>Neosho</areaDesc><geocode><valueName>UGC</valueName><value>KSZ096</value></geocode><geocode><valueName>SAME</valueName><value>020133</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>KBlZxVn4bls8+Fqu7Plks2Q1HMEIqit8Q692Rnn4Mn0=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN_200032+UID=100231113,OU=Devices,OU=FEMA,OU=Department of Homeland Security,O=U.S. Government,C=US</X509SubjectName><X509Certificate>\n/wQEAwIGwDAlBgNVHSAEHjAcMAwGCmCGSAFlAwIBAwYwDAYKY ...
#     "identifier": "NWS-130404-607269",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2013-11-07T22:46:55.000Z",
#     "status": "Actual",
#     "msgType": "Alert",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": null,
#     "searchGeometry": null,
#     "incidents": null,
#     "cogId": 200032,
#     "id": "00002650-39f0-455b-8112-046fdf66a10b",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 35,
#                 "name": "UGC",
#                 "value": "KSZ096"
#               },
#               {
#                 "id": 178,
#                 "name": "SAME",
#                 "value": "020133"
#               }
#             ],
#             "areaDesc": "Neosho"
#           }
#         ],
#         "event": "Extreme Fire Danger",
#         "onset": "2013-11-07T16:46:00-06:00",
#         "expires": "2013-11-08T11:00:00-06:00",
#         "urgency": "Expected",
#         "category": [
#           "Met"
#         ],
#         "headline": "Extreme Fire Danger issued November 7 at 4:46PM CST by NWS Wichita KS",
#         "severity": "Moderate",
#         "certainty": "Likely",
#         "effective": "2013-11-07T16:46:55-06:00",
#         "eventCode": [
#           {
#             "id": 263,
#             "name": "SAME",
#             "value": "OTH"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "PIL",
#             "value": "ICTRFDICT"
#           }
#         ],
#         "senderName": "NWS Wichita KS",
#         "description": "THE GFDI DOES NOT ACCOUNT FOR PRECIPITATION THAT OCCURS WITHIN\nTHE HOUR PRECEDING ANY GIVEN FORECAST HOUR BELOW OR ANY SNOW ON\nTHE GROUND AT THE FORECAST HOUR. PLEASE MAKE APPROPRIATE ADJUSTMENTS.(ALL TIME REFERENCES ARE IN CST)\n\nDAY/DATE      24HR INDEX   *  MID  3AM  6AM  9AM NOON  3PM  6PM  9PM\nTHU NOV 07  LOW         0  *                                 L    L  \nFRI NOV 08  MODERATE    3  *   L    L    L    L    L    M    L    L  \nSAT NOV 09  LOW         1  *   L    L    L    L    L    L    L    L  \nSUN NOV 10  LOW         0  *   L    L    L    L    L    L    L    L  \nMON NOV 11  LOW         0  *   L    L    L    L    L    L    L    L  \nTUE NOV 12  LOW         0  *   L    L    L    L    L    L    L    L",
#         "instruction": "",
#         "responseType": [
#           "Prepare"
#         ]
#       }
#     ]
#   },
#   {
#     "originalMessage": "<?xml version=\"1.0\" encoding=\"UTF-8\" standalone=\"yes\"?><alert xmlns=\"urn:oasis:names:tc:emergency:cap:1.2\"><identifier>NWS-IDP-PROD-2078547-1938011</identifier><sender>w-nws.webmaster@noaa.gov</sender><sent>2016-09-12T13:52:16-07:00</sent><status>Actual</status><msgType>Alert</msgType><scope>Public</scope><code>IPAWSv1.0</code><info><category>Met</category><event>Flood Advisory</event><responseType>Avoid</responseType><urgency>Expected</urgency><severity>Minor</severity><certainty>Likely</certainty><eventCode><valueName>SAME</valueName><value>NWS</value></eventCode><eventCode><valueName>NationalWeatherService</valueName><value>FAY</value></eventCode><effective>2016-09-12T13:52:16-07:00</effective><onset>2016-09-12T13:52:00-07:00</onset><expires>2016-09-12T16:45:00-07:00</expires><senderName>NWS Tucson AZ</senderName><headline>Flood Advisory issued September 12 at 1:52PM MST expiring September 12 at 4:45PM MST by NWS Tucson AZ</headline><description>THE NATIONAL WEATHER SERVICE IN TUCSON HAS ISSUED A\n\n* SMALL STREAM FLOOD ADVISORY FOR POOR DRAINAGE AREAS FOR...\nEAST CENTRAL PINAL COUNTY IN SOUTHEASTERN ARIZONA...\n\n* UNTIL 445 PM MST\n\n* AT 147 PM MST...DOPPLER RADAR INDICATED THAT A SERIES OF\nTHUNDERSTORMS WITH HEAVY RAIN HAS MOVED OVER THE SAME AREAS SOUTH\nAND EAST OF DUDLEYVILLE SINCE JUST BEFORE 12 NOON. UP TO TWO\nINCHES MAY HAVE ALREADY FALLEN, POSSLBLY HIGHER EAST OF STATE\nHIGHWAY 77, WHICH COULD CAUSE SMALL STREAM FLOODING ESPECIALLY IN\nPOOR DRAINAGE AREAS. ADDITIONAL THUNDERSTORMS MAY MOVE ACROSS THIS\nAREA FOR THE REMAINDER OF THE AFTERNOON HOURS\n\n* SOME LOCATIONS THAT MAY EXPERIENCE FLOODING INCLUDE...\nDUDLEYVILLE.</description><instruction></instruction><web>http://www.weather.gov</web><parameter><valueName>VTEC</valueName><value>/O.NEW.KTWC.FA.Y.0103.160912T2052Z-160912T2345Z/</value></parameter><parameter><valueName>PIL</valueName><value>TWCFLSTWC</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>CMAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>EAS</value></parameter><parameter><valueName>BLOCKCHANNEL</valueName><value>NWEM</value></parameter><parameter><valueName>eventEndingTime</valueName><value>2016-09-12T16:45:00-07:00</value></parameter><area><areaDesc>Pinal</areaDesc><polygon>32.97,-110.61 32.89,-110.56 32.84,-110.75 32.9,-110.78 32.97,-110.61</polygon><geocode><valueName>UGC</valueName><value>AZC021</value></geocode><geocode><valueName>SAME</valueName><value>004021</value></geocode></area></info><Signature xmlns=\"http://www.w3.org/2000/09/xmldsig#\"><SignedInfo><CanonicalizationMethod Algorithm=\"http://www.w3.org/2001/10/xml-exc-c14n#\"/><SignatureMethod Algorithm=\"http://www.w3.org/2001/04/xmldsig-more#rsa-sha256\"/><Reference URI=\"\"><Transforms><Transform Algorithm=\"http://www.w3.org/2000/09/xmldsig#enveloped-signature\"/></Transforms><DigestMethod Algorithm=\"http://www.w3.org/2001/04/xmlenc#sha256\"/><DigestValue>LQ4T3ldNPM7ZpbvYYjtppLtSsj4cqE5/P23P+8QRg8E=</DigestValue></Reference></SignedInfo><SignatureValue></SignatureValue><KeyInfo><X509Data><X509SubjectName>CN=IPAWSOPEN_200032,OU=Devices,OU=FEMA,OU=Department of Homeland Security,O=U.S. Government,C=US</X509SubjectName><X509Certificate> ...
#     "identifier": "NWS-IDP-PROD-2078547-1938011",
#     "sender": "w-nws.webmaster@noaa.gov",
#     "sent": "2016-09-12T20:52:16.000Z",
#     "status": "Actual",
#     "msgType": "Alert",
#     "source": null,
#     "scope": "Public",
#     "restriction": null,
#     "addresses": null,
#     "code": [
#       "IPAWSv1.0"
#     ],
#     "note": null,
#     "searchGeometry": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -110.61,
#             32.97
#           ],
#           [
#             -110.78,
#             32.9
#           ],
#           [
#             -110.75,
#             32.84
#           ],
#           [
#             -110.56,
#             32.89
#           ],
#           [
#             -110.61,
#             32.97
#           ]
#         ]
#       ]
#     },
#     "incidents": null,
#     "cogId": 200032,
#     "id": "0000266e-e9a8-4722-8220-ff9321e7a544",
#     "xmlns": "urn:oasis:names:tc:emergency:cap:1.2",
#     "info": [
#       {
#         "web": "http://www.weather.gov",
#         "areas": [
#           {
#             "geocode": [
#               {
#                 "id": 97324,
#                 "name": "UGC",
#                 "value": "AZC021"
#               },
#               {
#                 "id": 54434,
#                 "name": "SAME",
#                 "value": "004021"
#               }
#             ],
#             "polygon": {
#               "type": "Polygon",
#               "coordinates": [
#                 [
#                   [
#                     -110.61,
#                     32.97
#                   ],
#                   [
#                     -110.56,
#                     32.89
#                   ],
#                   [
#                     -110.75,
#                     32.84
#                   ],
#                   [
#                     -110.78,
#                     32.9
#                   ],
#                   [
#                     -110.61,
#                     32.97
#                   ]
#                 ]
#               ]
#             },
#             "areaDesc": "Pinal"
#           }
#         ],
#         "event": "Flood Advisory",
#         "onset": "2016-09-12T13:52:00-07:00",
#         "expires": "2016-09-12T16:45:00-07:00",
#         "urgency": "Expected",
#         "category": [
#           "Met"
#         ],
#         "headline": "Flood Advisory issued September 12 at 1:52PM MST expiring September 12 at 4:45PM MST by NWS Tucson AZ",
#         "severity": "Minor",
#         "certainty": "Likely",
#         "effective": "2016-09-12T13:52:16-07:00",
#         "eventCode": [
#           {
#             "id": 1582,
#             "name": "SAME",
#             "value": "NWS"
#           },
#           {
#             "id": 1612,
#             "name": "NationalWeatherService",
#             "value": "FAY"
#           }
#         ],
#         "parameters": [
#           {
#             "name": "VTEC",
#             "value": "/O.NEW.KTWC.FA.Y.0103.160912T2052Z-160912T2345Z/"
#           },
#           {
#             "name": "PIL",
#             "value": "TWCFLSTWC"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "CMAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "EAS"
#           },
#           {
#             "name": "BLOCKCHANNEL",
#             "value": "NWEM"
#           },
#           {
#             "name": "eventEndingTime",
#             "value": "2016-09-12T16:45:00-07:00"
#           }
#         ],
#         "senderName": "NWS Tucson AZ",
#         "description": "THE NATIONAL WEATHER SERVICE IN TUCSON HAS ISSUED A\n\n* SMALL STREAM FLOOD ADVISORY FOR POOR DRAINAGE AREAS FOR...\nEAST CENTRAL PINAL COUNTY IN SOUTHEASTERN ARIZONA...\n\n* UNTIL 445 PM MST\n\n* AT 147 PM MST...DOPPLER RADAR INDICATED THAT A SERIES OF\nTHUNDERSTORMS WITH HEAVY RAIN HAS MOVED OVER THE SAME AREAS SOUTH\nAND EAST OF DUDLEYVILLE SINCE JUST BEFORE 12 NOON. UP TO TWO\nINCHES MAY HAVE ALREADY FALLEN, POSSLBLY HIGHER EAST OF STATE\nHIGHWAY 77, WHICH COULD CAUSE SMALL STREAM FLOODING ESPECIALLY IN\nPOOR DRAINAGE AREAS. ADDITIONAL THUNDERSTORMS MAY MOVE ACROSS THIS\nAREA FOR THE REMAINDER OF THE AFTERNOON HOURS\n\n* SOME LOCATIONS THAT MAY EXPERIENCE FLOODING INCLUDE...\nDUDLEYVILLE.",
#         "instruction": "",
#         "responseType": [
#           "Avoid"
#         ]
#       }
#     ]
#   }
# ]

# %% [markdown]
# # This data provides detailed information about an alert issued by the National Weather Service (NWS) through the Integrated Public Alert and Warning System (IPAWS). Let's break down the key elements:
#
# Identifier: NWS-IDP-PROD-4445954-3699490 - A unique ID for the alert.
#
# Sender: w-nws.webmaster@noaa.gov - The email address of the sender.
#
# Sent: 2020-09-16T00:03:00.000Z - The date and time the alert was sent.
#
# Status: Actual - Indicates that the alert is real and not a test.
#
# MsgType: Update - Specifies that this message is an update to a previous alert.
#
# Scope: Public - The alert is intended for the public.
#
# Code: ["IPAWSv1.0"] - Identifies the version of IPAWS used.
#
# Id: 00000225-230a-4c98-acbf-9c9eccdface5 - A unique identifier for the record.
#
# XML Namespace: urn:oasis:names:tc:emergency:cap:1.2 - The XML namespace used for the alert.
#
# ## Information Object:
#
# Web: http://www.weather.gov - A URL for more information.
#
# ### Areas:
#
# - Geocode: Geographic codes for the alert areas.
#
# - Area Description: Coastal Citrus; Coastal Levy - The affected areas.
#
# Event: Coastal Flood Advisory - The type of event.
#
# Onset: 2020-09-15T20:03:00-04:00 - When the event starts.
#
# Expires: 2020-09-17T18:00:00-04:00 - When the event ends.
#
# Urgency: Expected - The expected level of urgency.
#
# Category: Met - Meteorological event.
#
# Headline: Provides a summary of the alert.
#
# Language: en-US - The language used in the alert.
#
# Severity: Minor - The level of severity.
#
# Certainty: Likely - The likelihood of the event.
#
# Effective: 2020-09-15T20:03:00-04:00 - When the alert becomes effective.
#
# Event Code: Additional identifiers for the event.
#
# Parameters: Additional parameters relevant to the alert, such as:
#
#  - NWSheadline: Headline for the advisory.
#
# - VTEC: VTEC (Valid Time Event Code) string.
#
# - PIL: Product Identifier.
#
# - BLOCKCHANNEL: Channels blocked for the alert.
#
# - eventEndingTime: When the event ends.
#
# Sender Name: NWS Tampa Bay Ruskin FL - The sender's name.
#
# Description: Detailed description of the event.
#
# Instruction: Instructions for the public.
#
# Response Type: Monitor - The type of response required.

# %%
import urllib.request
import json

# Define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# Define a query using parameters 
#select = "?$select=disasterNumber,declarationDate,declarationTitle,state"    # leave this parameter out if you want all fields
#filter = "&$filter=state%20ne%20%27FL%27"                                    # for purposes of example, exclude Florida
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # Issue API call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Extract the first record
    record = jsonData['IpawsArchivedAlerts'][0:10]
    
    # Extract specific elements (example: identifier, sender, sent date)
    identifier = record['identifier']
    sender = record['sender']
    sent = record['sent']
    event = record['info'][0]['event']
    description = record['info'][0]['description']
    
    # Extract coordinates from searchGeometry if it exists
    searchGeometry = record.get('searchGeometry', None)
    if searchGeometry is not None:
        coordinates = searchGeometry.get('coordinates', None)
    else:
        coordinates = "No coordinates available"
    
    # Extract area details from info object
    areas = record['info'][0]['areas'][0]
    area_desc = areas['areaDesc']
    geocode = areas['geocode']
    
    # Check if 'polygon' key exists
    polygon = areas.get('polygon', None)
    if polygon is not None:
        polygon_coords = polygon.get('coordinates', None)
    else:
        polygon_coords = "No polygon coordinates available"
    
    print(f"Identifier: {identifier}")
    print(f"Sender: {sender}")
    print(f"Sent: {sent}")
    print(f"Event: {event}")
    print(f"Description: {description}")
    print(f"Coordinates: {coordinates}")
    print(f"Area Description: {area_desc}")
    print("Geocode:")
    for code in geocode:
        print(f"  {code['name']}: {code['value']}")
    print(f"Polygon Coordinates: {polygon_coords}")

except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")
except KeyError as e:
    print(f"KeyError: Missing key {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 25
#      22 record = jsonData['IpawsArchivedAlerts'][0:10]
#      24 # Extract specific elements (example: identifier, sender, sent date)
# ---> 25 identifier = record['identifier']
#      26 sender = record['sender']
#      27 sent = record['sent']
#
# TypeError: list indices must be integers or slices, not str

# %%
import urllib.request
import json

# Define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# Define a query using parameters 
#select = "?$select=disasterNumber,declarationDate,declarationTitle,state"    # leave this parameter out if you want all fields
#filter = "&$filter=state%20ne%20%27FL%27"                                    # for purposes of example, exclude Florida
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # Issue API call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Extract the first 10 records
    records = jsonData['IpawsArchivedAlerts'][0:10]
    
    for record in records:
        # Extract specific elements (example: identifier, sender, sent date)
        identifier = record['identifier']
        sender = record['sender']
        sent = record['sent']
        event = record['info'][0]['event']
        description = record['info'][0]['description']
        
        # Extract coordinates from searchGeometry if it exists
        searchGeometry = record.get('searchGeometry', None)
        if searchGeometry is not None:
            coordinates = searchGeometry.get('coordinates', None)
        else:
            coordinates = "No coordinates available"
        
        # Extract area details from info object
        areas = record['info'][0]['areas'][0]
        area_desc = areas['areaDesc']
        geocode = areas['geocode']
        
        # Check if 'polygon' key exists
        polygon = areas.get('polygon', None)
        if polygon is not None:
            polygon_coords = polygon.get('coordinates', None)
        else:
            polygon_coords = "No polygon coordinates available"
        
        print(f"Identifier: {identifier}")
        print(f"Sender: {sender}")
        print(f"Sent: {sent}")
        print(f"Event: {event}")
        print(f"Description: {description}")
        print(f"Coordinates: {coordinates}")
        print(f"Area Description: {area_desc}")
        print("Geocode:")
        for code in geocode:
            print(f"  {code['name']}: {code['value']}")
        print(f"Polygon Coordinates: {polygon_coords}")
        print("-" * 40)

except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")
except KeyError as e:
    print(f"KeyError: Missing key {e}")
# Out:
# Identifier: NWS-IDP-PROD-4445954-3699490
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2020-09-16T00:03:00.000Z
# Event: Coastal Flood Advisory
# Description: * COASTAL FLOODING...A combination of abnormally high tides and
# surge from Sally will allow water levels to run 2 to 3 feet
# Above Ground Level (3.5 to 4.5 feet MSL) during times of high
# tide through Thursday.
#
# * COASTAL FLOOD TIMING...During afternoon high tides through
# Thursday.
#
# * COASTAL FLOOD IMPACTS...Minor coastal flooding, especially low-
# lying roads or other areas sensitive to nuisance flooding.
# Coordinates: No coordinates available
# Area Description: Coastal Citrus; Coastal Levy
# Geocode:
#   UGC: FLZ142
#   UGC: FLZ139
#   SAME: 012017
#   SAME: 012075
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-IDP-PROD-4767760-3849910
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2021-02-06T19:12:00.000Z
# Event: Small Craft Advisory
# Description: * WHAT...North winds 15 to 20 kt with gusts up to 25 kt and
# waves around 2 ft expected.
#
# * WHERE...Currituck Sound.
#
# * WHEN...From 4 AM to 4 PM EST Sunday.
#
# * IMPACTS...Conditions will be hazardous to small craft.
# Coordinates: No coordinates available
# Area Description: Currituck Sound
# Geocode:
#   UGC: ANZ633
#   SAME: 073633
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-141029-1252843-1199419
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2016-04-16T03:02:08.000Z
# Event: Severe Thunderstorm Warning
# Description: THE NATIONAL WEATHER SERVICE IN DODGE CITY HAS ISSUED A
#
# * SEVERE THUNDERSTORM WARNING FOR...
#   SOUTHEASTERN HAMILTON COUNTY IN SOUTHWESTERN KANSAS...
#   NORTHEASTERN STANTON COUNTY IN SOUTHWESTERN KANSAS...
#   SOUTHWESTERN KEARNY COUNTY IN SOUTHWESTERN KANSAS...
#   NORTHERN GRANT COUNTY IN SOUTHWESTERN KANSAS...
#
# * UNTIL 1045 PM CDT/945 PM MDT/
#
# * AT 1001 PM CDT/901 PM MDT/...A SEVERE THUNDERSTORM WAS LOCATED VERY
#   NEAR JOHNSON CITY...MOVING NORTHEAST AT 25 MPH.
#
#   HAZARD...QUARTER SIZE HAIL.
#
#   SOURCE...RADAR INDICATED.
#
#   IMPACT...DAMAGE TO VEHICLES IS EXPECTED.
#
# * LOCATIONS IMPACTED INCLUDE...
#   JOHNSON CITY AND BIG BOW.
# Coordinates: [[[-101.69, 37.5], [-101.16, 37.68], [-101.36, 37.92], [-101.87, 37.72], [-101.69, 37.5]]]
# Area Description: Stanton; Hamilton; Grant; Kearny
# Geocode:
#   UGC: KSC067
#   UGC: KSC093
#   UGC: KSC075
#   UGC: KSC187
#   SAME: 020187
#   SAME: 020075
#   SAME: 020067
#   SAME: 020093
# Polygon Coordinates: [[[-101.69, 37.5], [-101.87, 37.72], [-101.36, 37.92], [-101.16, 37.68], [-101.69, 37.5]]]
# ----------------------------------------
# Identifier: NWS-IDP-PROD-3927867
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2019-11-26T14:24:00.000Z
# Event: Special Weather Statement
# Description: Snow is expected to develop on Wednesday morning over the eastern
# Kenai Peninsula and become heavier by afternoon. Easterly winds
# through Turnagain Arm are also expected to increase on Wednesday
# and bring the potential for periods of reduced visibility along
# the highway due to blowing snow. Warmer air moving into the
# region will start to turn the snow to rain in Seward and Turnagain
# Arm Wednesday night and continue as rain into Thursday in those
# locations.
#
# For Turnagain Pass, precipitation is likely to remain snow
# through Thursday with periods of reduced visibility in blowing
# snow.
#
# Stay tuned to the latest forecasts at weather.gov/Anchorage.
# Coordinates: No coordinates available
# Area Description: Western Prince William Sound
# Geocode:
#   UGC: AKZ125
#   SAME: 002261
#   SAME: 002122
#   SAME: 002020
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: urn:oid:2.49.0.1.840.0.15e3aa787d8309418977a87815a01da8bbef682c.001.1
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2022-04-16T06:48:00.000Z
# Event: Severe Thunderstorm Warning
# Description: The Severe Thunderstorm Warning has been cancelled and is no longer in effect.
# Coordinates: [[[-95.71, 35.55], [-95.76, 35.55], [-95.73, 35.48], [-95.49, 35.4], [-95.52, 35.55], [-95.51, 35.6], [-95.71, 35.59], [-95.71, 35.55]]]
# Area Description: Okmulgee, OK
# Geocode:
#   SAME: 040111
#   UGC: OKC111
# Polygon Coordinates: [[[-95.71, 35.55], [-95.71, 35.59], [-95.51, 35.6], [-95.52, 35.55], [-95.49, 35.4], [-95.73, 35.48], [-95.76, 35.55], [-95.71, 35.55]]]
# ----------------------------------------
# Identifier: NWS-IDP-PROD-2775732-2588301
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2018-04-17T01:26:18.000Z
# Event: Flood Advisory
# Description: Kankakee River at Dunns Bridge affecting Porter County
# Kankakee River near Kouts affecting Jasper and Porter Counties
# The Flood Advisory continues for
# The Kankakee River near Kouts
# * until Friday evening.
# * At  800 PM Monday the stage was 8.7 feet.
# * Action stage is 10.5 feet.
# * Flood stage is 11.0 feet.
# * Forecast...The river will rise to near 10.6 feet by early Thursday
# morning.
# * Impact...At 11.0 feet...Agricultural areas begin to flood. Some
# backwaters begin to fill drainage ditches.
#
# Coordinates: [[[-87.06, 41.22], [-87, 41.28], [-87.13, 41.32], [-87.27, 41.27], [-87.23, 41.18], [-87.11, 41.22], [-87.06, 41.22]]]
# Area Description: Jasper, IN; Porter, IN
# Geocode:
#   UGC: INC073
#   UGC: INC127
#   SAME: 018073
#   SAME: 018127
# Polygon Coordinates: [[[-87.06, 41.22], [-87.11, 41.22], [-87.23, 41.18], [-87.27, 41.27], [-87.13, 41.32], [-87, 41.28], [-87.06, 41.22]]]
# ----------------------------------------
# Identifier: NWS-IDP-PROD-4704631-3822344
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2021-01-16T01:35:00.000Z
# Event: Lake Wind Advisory
# Description: * WHAT...West winds 15 to 20 knots with gusts up to 25 knots and
# waves 1 to 2 feet expected.
#
# * WHERE...Lake Moultrie.
#
# * WHEN...From 11 AM to 6 PM EST Saturday.
#
# * IMPACTS...Strong winds and rough waves on Lake Moultrie will
# create hazardous conditions for small craft.
# Coordinates: No coordinates available
# Area Description: Inland Berkeley
# Geocode:
#   UGC: SCZ045
#   SAME: 045015
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-IDP-PROD-4522684-3753160
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2020-11-10T22:38:00.000Z
# Event: Severe Thunderstorm Warning
# Description: The National Weather Service in Chicago has issued a
#
# * Severe Thunderstorm Warning for...
# Lake County in northeastern Illinois...
# Eastern McHenry County in northeastern Illinois...
# DuPage County in northeastern Illinois...
# Northern Cook County in northeastern Illinois...
#
# * Until 600 PM CST.
#
# * At 435 PM CST, severe thunderstorms were located along a line
# extending from Richmond to near DeKalb to near Plano, moving
# northeast at 55 mph.
#
# HAZARD...70 mph wind gusts and penny size hail.
#
# SOURCE...Trained weather spotters. These storms have a history of
# producing damaging 70 mph winds west of the Chicago metro.
#
# IMPACT...Expect considerable tree damage. Damage is likely to
# mobile homes, roofs, and outbuildings.
#
# * Locations impacted include...
# Northwest side of Chicago, Aurora, Naperville, Elgin, Waukegan,
# Arlington Heights, Evanston, Schaumburg, Bolingbrook, Palatine,
# Skokie, Des Plaines, Berwyn, Mount Prospect, Wheaton, Hoffman
# Estates, Oak Park, Downers Grove, Glenview and Elmhurst.
#
# This includes...Argonne National Laboratory, Brookfield Zoo, Oakton
# Community College, Triton College, Benedictine University, Chain O
# Lakes State Park, College of DuPage, College of Lake County, Great
# Lakes Naval Training Center, Harper College, Lake Forest College,
# Mchenry County College, Moraine Hills State Park, Morton Arboretum,
# Northeastern Illinois University, Northwestern University, Wheaton
# College, and North Central College.
# Coordinates: [[[-87.8, 42.49], [-88.25, 42.5], [-88.44, 42.16], [-88.24, 42.15], [-88.24, 42.07], [-88.26, 42.07], [-88.26, 41.73], [-88.03, 41.73], [-88.03, 41.69], [-87.96, 41.69], [-87.91, 41.72], [-87.66, 42.01], [-87.67, 42.06], [-87.74, 42.13], [-87.83, 42.27], [-87.8, 42.49]]]
# Area Description: McHenry, IL; DuPage, IL; Cook, IL; Lake, IL
# Geocode:
#   UGC: ILC111
#   UGC: ILC043
#   UGC: ILC031
#   UGC: ILC097
#   SAME: 017111
#   SAME: 017043
#   SAME: 017031
#   SAME: 017097
# Polygon Coordinates: [[[-87.8, 42.49], [-87.83, 42.27], [-87.74, 42.13], [-87.67, 42.06], [-87.66, 42.01], [-87.91, 41.72], [-87.96, 41.69], [-88.03, 41.69], [-88.03, 41.73], [-88.26, 41.73], [-88.26, 42.07], [-88.24, 42.07], [-88.24, 42.15], [-88.44, 42.16], [-88.25, 42.5], [-87.8, 42.49]]]
# ----------------------------------------
# Identifier: NWS-130404-607269
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2013-11-07T22:46:55.000Z
# Event: Extreme Fire Danger
# Description: THE GFDI DOES NOT ACCOUNT FOR PRECIPITATION THAT OCCURS WITHIN
# THE HOUR PRECEDING ANY GIVEN FORECAST HOUR BELOW OR ANY SNOW ON
# THE GROUND AT THE FORECAST HOUR. PLEASE MAKE APPROPRIATE ADJUSTMENTS.(ALL TIME REFERENCES ARE IN CST)
#
# DAY/DATE      24HR INDEX   *  MID  3AM  6AM  9AM NOON  3PM  6PM  9PM
# THU NOV 07  LOW         0  *                                 L    L
# FRI NOV 08  MODERATE    3  *   L    L    L    L    L    M    L    L
# SAT NOV 09  LOW         1  *   L    L    L    L    L    L    L    L
# SUN NOV 10  LOW         0  *   L    L    L    L    L    L    L    L
# MON NOV 11  LOW         0  *   L    L    L    L    L    L    L    L
# TUE NOV 12  LOW         0  *   L    L    L    L    L    L    L    L
# Coordinates: No coordinates available
# Area Description: Neosho
# Geocode:
#   UGC: KSZ096
#   SAME: 020133
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-IDP-PROD-2078547-1938011
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2016-09-12T20:52:16.000Z
# Event: Flood Advisory
# Description: THE NATIONAL WEATHER SERVICE IN TUCSON HAS ISSUED A
#
# * SMALL STREAM FLOOD ADVISORY FOR POOR DRAINAGE AREAS FOR...
# EAST CENTRAL PINAL COUNTY IN SOUTHEASTERN ARIZONA...
#
# * UNTIL 445 PM MST
#
# * AT 147 PM MST...DOPPLER RADAR INDICATED THAT A SERIES OF
# THUNDERSTORMS WITH HEAVY RAIN HAS MOVED OVER THE SAME AREAS SOUTH
# AND EAST OF DUDLEYVILLE SINCE JUST BEFORE 12 NOON. UP TO TWO
# INCHES MAY HAVE ALREADY FALLEN, POSSLBLY HIGHER EAST OF STATE
# HIGHWAY 77, WHICH COULD CAUSE SMALL STREAM FLOODING ESPECIALLY IN
# POOR DRAINAGE AREAS. ADDITIONAL THUNDERSTORMS MAY MOVE ACROSS THIS
# AREA FOR THE REMAINDER OF THE AFTERNOON HOURS
#
# * SOME LOCATIONS THAT MAY EXPERIENCE FLOODING INCLUDE...
# DUDLEYVILLE.
# Coordinates: [[[-110.61, 32.97], [-110.78, 32.9], [-110.75, 32.84], [-110.56, 32.89], [-110.61, 32.97]]]
# Area Description: Pinal
# Geocode:
#   UGC: AZC021
#   SAME: 004021
# Polygon Coordinates: [[[-110.61, 32.97], [-110.56, 32.89], [-110.75, 32.84], [-110.78, 32.9], [-110.61, 32.97]]]
# ----------------------------------------

# %% [markdown]
# # Install geopy

# %%
from geopy.geocoders import OpenCage
from geopy.exc import GeocoderTimedOut

def get_coordinates_opencage(area_name, api_key):
    geolocator = OpenCage(api_key)
    try:
        location = geolocator.geocode(area_name)
        if location:
            return (location.latitude, location.longitude)
        else:
            return None
    except GeocoderTimedOut:
        return None

# Example usage
area_name = "Coastal Citrus"
api_key = "091322c2c53048edbe1d12dd1b24c0d2"  # Replace with your actual OpenCage API key
coordinates = get_coordinates_opencage(area_name, api_key)
if coordinates:
    print(f"Coordinates for {area_name}: {coordinates}")
else:
    print(f"Coordinates not found for {area_name}")
# Out:
# Coordinates for Coastal Citrus: (28.9026087, -82.5771459)

# %%
import urllib.request
import json
from geopy.geocoders import OpenCage
from geopy.exc import GeocoderTimedOut

def get_coordinates_opencage(area_name, api_key):
    geolocator = OpenCage(api_key)
    try:
        location = geolocator.geocode(area_name)
        if location:
            return (location.latitude, location.longitude)
        else:
            return None
    except GeocoderTimedOut:
        return None

# Define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# Define a query using parameters 
#select = "?$select=disasterNumber,declarationDate,declarationTitle,state"    # leave this parameter out if you want all fields
#filter = "&$filter=state%20ne%20%27FL%27"                                    # for purposes of example, exclude Florida
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # Issue API call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Extract the first 10 records
    records = jsonData['IpawsArchivedAlerts'][0:10]
    
    api_key = "091322c2c53048edbe1d12dd1b24c0d2"  # Replace with your actual OpenCage API key

    for record in records:
        # Extract specific elements (example: identifier, sender, sent date)
        identifier = record['identifier']
        sender = record['sender']
        sent = record['sent']
        event = record['info'][0]['event']
        description = record['info'][0]['description']
        
        # Extract coordinates from searchGeometry if it exists
        searchGeometry = record.get('searchGeometry', None)
        if searchGeometry is not None:
            coordinates = searchGeometry.get('coordinates', None)
        else:
            coordinates = "No coordinates available"
        
        # Extract area details from info object
        areas = record['info'][0]['areas'][0]
        area_desc = areas['areaDesc']
        geocode = areas['geocode']
        
        # Check if 'polygon' key exists
        polygon = areas.get('polygon', None)
        if polygon is not None:
            polygon_coords = polygon.get('coordinates', None)
        else:
            polygon_coords = "No polygon coordinates available"

        # Get coordinates for the area description using OpenCage
        area_coords = get_coordinates_opencage(area_desc, api_key)
        
        print(f"Identifier: {identifier}")
        print(f"Sender: {sender}")
        print(f"Sent: {sent}")
        print(f"Event: {event}")
        print(f"Description: {description}")
        print(f"Coordinates: {coordinates}")
        print(f"Area Description: {area_desc}")
        print(f"Area Coordinates: {area_coords}")
        print("Geocode:")
        for code in geocode:
            print(f"  {code['name']}: {code['value']}")
        print(f"Polygon Coordinates: {polygon_coords}")
        print("-" * 40)

except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")
except KeyError as e:
    print(f"KeyError: Missing key {e}")
# Out:
# Identifier: NWS-IDP-PROD-4445954-3699490
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2020-09-16T00:03:00.000Z
# Event: Coastal Flood Advisory
# Description: * COASTAL FLOODING...A combination of abnormally high tides and
# surge from Sally will allow water levels to run 2 to 3 feet
# Above Ground Level (3.5 to 4.5 feet MSL) during times of high
# tide through Thursday.
#
# * COASTAL FLOOD TIMING...During afternoon high tides through
# Thursday.
#
# * COASTAL FLOOD IMPACTS...Minor coastal flooding, especially low-
# lying roads or other areas sensitive to nuisance flooding.
# Coordinates: No coordinates available
# Area Description: Coastal Citrus; Coastal Levy
# Area Coordinates: (29.28221, -82.78861)
# Geocode:
#   UGC: FLZ142
#   UGC: FLZ139
#   SAME: 012017
#   SAME: 012075
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-IDP-PROD-4767760-3849910
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2021-02-06T19:12:00.000Z
# Event: Small Craft Advisory
# Description: * WHAT...North winds 15 to 20 kt with gusts up to 25 kt and
# waves around 2 ft expected.
#
# * WHERE...Currituck Sound.
#
# * WHEN...From 4 AM to 4 PM EST Sunday.
#
# * IMPACTS...Conditions will be hazardous to small craft.
# Coordinates: No coordinates available
# Area Description: Currituck Sound
# Area Coordinates: (36.3403242, -75.865911)
# Geocode:
#   UGC: ANZ633
#   SAME: 073633
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-141029-1252843-1199419
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2016-04-16T03:02:08.000Z
# Event: Severe Thunderstorm Warning
# Description: THE NATIONAL WEATHER SERVICE IN DODGE CITY HAS ISSUED A
#
# * SEVERE THUNDERSTORM WARNING FOR...
#   SOUTHEASTERN HAMILTON COUNTY IN SOUTHWESTERN KANSAS...
#   NORTHEASTERN STANTON COUNTY IN SOUTHWESTERN KANSAS...
#   SOUTHWESTERN KEARNY COUNTY IN SOUTHWESTERN KANSAS...
#   NORTHERN GRANT COUNTY IN SOUTHWESTERN KANSAS...
#
# * UNTIL 1045 PM CDT/945 PM MDT/
#
# * AT 1001 PM CDT/901 PM MDT/...A SEVERE THUNDERSTORM WAS LOCATED VERY
#   NEAR JOHNSON CITY...MOVING NORTHEAST AT 25 MPH.
#
#   HAZARD...QUARTER SIZE HAIL.
#
#   SOURCE...RADAR INDICATED.
#
#   IMPACT...DAMAGE TO VEHICLES IS EXPECTED.
#
# * LOCATIONS IMPACTED INCLUDE...
#   JOHNSON CITY AND BIG BOW.
# Coordinates: [[[-101.69, 37.5], [-101.16, 37.68], [-101.36, 37.92], [-101.87, 37.72], [-101.69, 37.5]]]
# Area Description: Stanton; Hamilton; Grant; Kearny
# Area Coordinates: (40.76843, -74.14542)
# Geocode:
#   UGC: KSC067
#   UGC: KSC093
#   UGC: KSC075
#   UGC: KSC187
#   SAME: 020187
#   SAME: 020075
#   SAME: 020067
#   SAME: 020093
# Polygon Coordinates: [[[-101.69, 37.5], [-101.87, 37.72], [-101.36, 37.92], [-101.16, 37.68], [-101.69, 37.5]]]
# ----------------------------------------
# Identifier: NWS-IDP-PROD-3927867
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2019-11-26T14:24:00.000Z
# Event: Special Weather Statement
# Description: Snow is expected to develop on Wednesday morning over the eastern
# Kenai Peninsula and become heavier by afternoon. Easterly winds
# through Turnagain Arm are also expected to increase on Wednesday
# and bring the potential for periods of reduced visibility along
# the highway due to blowing snow. Warmer air moving into the
# region will start to turn the snow to rain in Seward and Turnagain
# Arm Wednesday night and continue as rain into Thursday in those
# locations.
#
# For Turnagain Pass, precipitation is likely to remain snow
# through Thursday with periods of reduced visibility in blowing
# snow.
#
# Stay tuned to the latest forecasts at weather.gov/Anchorage.
# Coordinates: No coordinates available
# Area Description: Western Prince William Sound
# Area Coordinates: (60.615, -147.16806)
# Geocode:
#   UGC: AKZ125
#   SAME: 002261
#   SAME: 002122
#   SAME: 002020
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: urn:oid:2.49.0.1.840.0.15e3aa787d8309418977a87815a01da8bbef682c.001.1
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2022-04-16T06:48:00.000Z
# Event: Severe Thunderstorm Warning
# Description: The Severe Thunderstorm Warning has been cancelled and is no longer in effect.
# Coordinates: [[[-95.71, 35.55], [-95.76, 35.55], [-95.73, 35.48], [-95.49, 35.4], [-95.52, 35.55], [-95.51, 35.6], [-95.71, 35.59], [-95.71, 35.55]]]
# Area Description: Okmulgee, OK
# Area Coordinates: (35.6677078, -95.9690122)
# Geocode:
#   SAME: 040111
#   UGC: OKC111
# Polygon Coordinates: [[[-95.71, 35.55], [-95.71, 35.59], [-95.51, 35.6], [-95.52, 35.55], [-95.49, 35.4], [-95.73, 35.48], [-95.76, 35.55], [-95.71, 35.55]]]
# ----------------------------------------
# Identifier: NWS-IDP-PROD-2775732-2588301
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2018-04-17T01:26:18.000Z
# Event: Flood Advisory
# Description: Kankakee River at Dunns Bridge affecting Porter County
# Kankakee River near Kouts affecting Jasper and Porter Counties
# The Flood Advisory continues for
# The Kankakee River near Kouts
# * until Friday evening.
# * At  800 PM Monday the stage was 8.7 feet.
# * Action stage is 10.5 feet.
# * Flood stage is 11.0 feet.
# * Forecast...The river will rise to near 10.6 feet by early Thursday
# morning.
# * Impact...At 11.0 feet...Agricultural areas begin to flood. Some
# backwaters begin to fill drainage ditches.
#
# Coordinates: [[[-87.06, 41.22], [-87, 41.28], [-87.13, 41.32], [-87.27, 41.27], [-87.23, 41.18], [-87.11, 41.22], [-87.06, 41.22]]]
# Area Description: Jasper, IN; Porter, IN
# Area Coordinates: (39.692256, -86.13275)
# Geocode:
#   UGC: INC073
#   UGC: INC127
#   SAME: 018073
#   SAME: 018127
# Polygon Coordinates: [[[-87.06, 41.22], [-87.11, 41.22], [-87.23, 41.18], [-87.27, 41.27], [-87.13, 41.32], [-87, 41.28], [-87.06, 41.22]]]
# ----------------------------------------
# Identifier: NWS-IDP-PROD-4704631-3822344
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2021-01-16T01:35:00.000Z
# Event: Lake Wind Advisory
# Description: * WHAT...West winds 15 to 20 knots with gusts up to 25 knots and
# waves 1 to 2 feet expected.
#
# * WHERE...Lake Moultrie.
#
# * WHEN...From 11 AM to 6 PM EST Saturday.
#
# * IMPACTS...Strong winds and rough waves on Lake Moultrie will
# create hazardous conditions for small craft.
# Coordinates: No coordinates available
# Area Description: Inland Berkeley
# Area Coordinates: (37.87159, -122.27275)
# Geocode:
#   UGC: SCZ045
#   SAME: 045015
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-IDP-PROD-4522684-3753160
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2020-11-10T22:38:00.000Z
# Event: Severe Thunderstorm Warning
# Description: The National Weather Service in Chicago has issued a
#
# * Severe Thunderstorm Warning for...
# Lake County in northeastern Illinois...
# Eastern McHenry County in northeastern Illinois...
# DuPage County in northeastern Illinois...
# Northern Cook County in northeastern Illinois...
#
# * Until 600 PM CST.
#
# * At 435 PM CST, severe thunderstorms were located along a line
# extending from Richmond to near DeKalb to near Plano, moving
# northeast at 55 mph.
#
# HAZARD...70 mph wind gusts and penny size hail.
#
# SOURCE...Trained weather spotters. These storms have a history of
# producing damaging 70 mph winds west of the Chicago metro.
#
# IMPACT...Expect considerable tree damage. Damage is likely to
# mobile homes, roofs, and outbuildings.
#
# * Locations impacted include...
# Northwest side of Chicago, Aurora, Naperville, Elgin, Waukegan,
# Arlington Heights, Evanston, Schaumburg, Bolingbrook, Palatine,
# Skokie, Des Plaines, Berwyn, Mount Prospect, Wheaton, Hoffman
# Estates, Oak Park, Downers Grove, Glenview and Elmhurst.
#
# This includes...Argonne National Laboratory, Brookfield Zoo, Oakton
# Community College, Triton College, Benedictine University, Chain O
# Lakes State Park, College of DuPage, College of Lake County, Great
# Lakes Naval Training Center, Harper College, Lake Forest College,
# Mchenry County College, Moraine Hills State Park, Morton Arboretum,
# Northeastern Illinois University, Northwestern University, Wheaton
# College, and North Central College.
# Coordinates: [[[-87.8, 42.49], [-88.25, 42.5], [-88.44, 42.16], [-88.24, 42.15], [-88.24, 42.07], [-88.26, 42.07], [-88.26, 41.73], [-88.03, 41.73], [-88.03, 41.69], [-87.96, 41.69], [-87.91, 41.72], [-87.66, 42.01], [-87.67, 42.06], [-87.74, 42.13], [-87.83, 42.27], [-87.8, 42.49]]]
# Area Description: McHenry, IL; DuPage, IL; Cook, IL; Lake, IL
# Area Coordinates: (38.870965, -88.445763)
# Geocode:
#   UGC: ILC111
#   UGC: ILC043
#   UGC: ILC031
#   UGC: ILC097
#   SAME: 017111
#   SAME: 017043
#   SAME: 017031
#   SAME: 017097
# Polygon Coordinates: [[[-87.8, 42.49], [-87.83, 42.27], [-87.74, 42.13], [-87.67, 42.06], [-87.66, 42.01], [-87.91, 41.72], [-87.96, 41.69], [-88.03, 41.69], [-88.03, 41.73], [-88.26, 41.73], [-88.26, 42.07], [-88.24, 42.07], [-88.24, 42.15], [-88.44, 42.16], [-88.25, 42.5], [-87.8, 42.49]]]
# ----------------------------------------
# Identifier: NWS-130404-607269
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2013-11-07T22:46:55.000Z
# Event: Extreme Fire Danger
# Description: THE GFDI DOES NOT ACCOUNT FOR PRECIPITATION THAT OCCURS WITHIN
# THE HOUR PRECEDING ANY GIVEN FORECAST HOUR BELOW OR ANY SNOW ON
# THE GROUND AT THE FORECAST HOUR. PLEASE MAKE APPROPRIATE ADJUSTMENTS.(ALL TIME REFERENCES ARE IN CST)
#
# DAY/DATE      24HR INDEX   *  MID  3AM  6AM  9AM NOON  3PM  6PM  9PM
# THU NOV 07  LOW         0  *                                 L    L
# FRI NOV 08  MODERATE    3  *   L    L    L    L    L    M    L    L
# SAT NOV 09  LOW         1  *   L    L    L    L    L    L    L    L
# SUN NOV 10  LOW         0  *   L    L    L    L    L    L    L    L
# MON NOV 11  LOW         0  *   L    L    L    L    L    L    L    L
# TUE NOV 12  LOW         0  *   L    L    L    L    L    L    L    L
# Coordinates: No coordinates available
# Area Description: Neosho
# Area Coordinates: (37.5566345, -95.33166)
# Geocode:
#   UGC: KSZ096
#   SAME: 020133
# Polygon Coordinates: No polygon coordinates available
# ----------------------------------------
# Identifier: NWS-IDP-PROD-2078547-1938011
# Sender: w-nws.webmaster@noaa.gov
# Sent: 2016-09-12T20:52:16.000Z
# Event: Flood Advisory
# Description: THE NATIONAL WEATHER SERVICE IN TUCSON HAS ISSUED A
#
# * SMALL STREAM FLOOD ADVISORY FOR POOR DRAINAGE AREAS FOR...
# EAST CENTRAL PINAL COUNTY IN SOUTHEASTERN ARIZONA...
#
# * UNTIL 445 PM MST
#
# * AT 147 PM MST...DOPPLER RADAR INDICATED THAT A SERIES OF
# THUNDERSTORMS WITH HEAVY RAIN HAS MOVED OVER THE SAME AREAS SOUTH
# AND EAST OF DUDLEYVILLE SINCE JUST BEFORE 12 NOON. UP TO TWO
# INCHES MAY HAVE ALREADY FALLEN, POSSLBLY HIGHER EAST OF STATE
# HIGHWAY 77, WHICH COULD CAUSE SMALL STREAM FLOODING ESPECIALLY IN
# POOR DRAINAGE AREAS. ADDITIONAL THUNDERSTORMS MAY MOVE ACROSS THIS
# AREA FOR THE REMAINDER OF THE AFTERNOON HOURS
#
# * SOME LOCATIONS THAT MAY EXPERIENCE FLOODING INCLUDE...
# DUDLEYVILLE.
# Coordinates: [[[-110.61, 32.97], [-110.78, 32.9], [-110.75, 32.84], [-110.56, 32.89], [-110.61, 32.97]]]
# Area Description: Pinal
# Area Coordinates: (32.8085851, -111.4426212)
# Geocode:
#   UGC: AZC021
#   SAME: 004021
# Polygon Coordinates: [[[-110.61, 32.97], [-110.56, 32.89], [-110.75, 32.84], [-110.78, 32.9], [-110.61, 32.97]]]
# ----------------------------------------

# %%
import urllib.request
import json
import folium
from geopy.geocoders import OpenCage
from geopy.exc import GeocoderTimedOut

def get_coordinates_opencage(area_name, api_key):
    geolocator = OpenCage(api_key)
    try:
        location = geolocator.geocode(area_name)
        if location:
            return (location.latitude, location.longitude)
        else:
            return None
    except GeocoderTimedOut:
        return None

# Define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# Define a query using parameters 
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # Issue API call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Extract the first 10 records
    records = jsonData['IpawsArchivedAlerts'][0:10]
    
    api_key = "091322c2c53048edbe1d12dd1b24c0d2"  # Replace with your actual OpenCage API key

    # Create a map centered on the US
    m = folium.Map(location=[37.0902, -95.7129], zoom_start=5)
    
    for record in records:
        # Extract specific elements (example: identifier, sender, sent date)
        identifier = record['identifier']
        sender = record['sender']
        sent = record['sent']
        event = record['info'][0]['event']
        description = record['info'][0]['description']
        
        # Extract coordinates from searchGeometry if it exists
        searchGeometry = record.get('searchGeometry', None)
        if searchGeometry is not None:
            coordinates = searchGeometry.get('coordinates', None)
        else:
            coordinates = "No coordinates available"
        
        # Extract area details from info object
        areas = record['info'][0]['areas'][0]
        area_desc = areas['areaDesc']
        geocode = areas['geocode']
        
        # Check if 'polygon' key exists
        polygon = areas.get('polygon', None)
        if polygon is not None:
            polygon_coords = polygon.get('coordinates', None)
        else:
            polygon_coords = "No polygon coordinates available"

        # Get coordinates for the area description using OpenCage
        area_coords = get_coordinates_opencage(area_desc, api_key)
        
        if area_coords:
            # Add a marker for the alert
            folium.Marker(
                location=area_coords,
                popup=f"{event}\n{description}",
                tooltip=identifier,
            ).add_to(m)
        
        if polygon_coords and polygon_coords != "No polygon coordinates available":
            # Add a polygon to the map
            folium.Polygon(
                locations=polygon_coords[0],
                color='blue',
                fill=True,
                fill_opacity=0.4
            ).add_to(m)

    # Save the map to an HTML file
    m.save('alerts_map.html')
    print("Map has been created and saved as 'alerts_map.html'")

except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")
except KeyError as e:
    print(f"KeyError: Missing key {e}")
# Out:
# Map has been created and saved as 'alerts_map.html'

# %%
import urllib.request
import json
import folium
import requests

def get_coordinates_positionstack(area_name, api_key):
    url = f"http://api.positionstack.com/v1/forward"
    params = {
        'access_key': api_key,
        'query': area_name,
        'limit': 1
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data['data']:
            location = data['data'][0]
            return (location['latitude'], location['longitude'])
        else:
            return None
    else:
        return None

# Define URL for the Disaster Declarations Summaries endpoint
baseUrl = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"

# Define a query using parameters 
orderby = "?$orderby=id"                                                     
format = "&$format=json"    

try:
    # Issue API call
    request = urllib.request.urlopen(baseUrl + orderby + format)
    result = request.read()

    # Load the result into a JSON object
    jsonData = json.loads(result.decode())
    
    # Extract the first 10 records
    records = jsonData['IpawsArchivedAlerts'][0:1000]
    
    api_key = "dee35a4efb54c711df6c07e4d1c0d303"  # Replace with your actual PositionStack API key

    # Create a map centered on the US
    m = folium.Map(location=[37.0902, -95.7129], zoom_start=5)
    
    for record in records:
        # Extract specific elements (example: identifier, sender, sent date)
        identifier = record['identifier']
        sender = record['sender']
        sent = record['sent']
        event = record['info'][0]['event']
        description = record['info'][0]['description']
        
        # Extract coordinates from searchGeometry if it exists
        searchGeometry = record.get('searchGeometry', None)
        if searchGeometry is not None:
            coordinates = searchGeometry.get('coordinates', None)
        else:
            coordinates = "No coordinates available"
        
        # Extract area details from info object
        areas = record['info'][0]['areas'][0]
        area_desc = areas['areaDesc']
        geocode = areas['geocode']
        
        # Check if 'polygon' key exists
        polygon = areas.get('polygon', None)
        if polygon is not None:
            polygon_coords = polygon.get('coordinates', None)
        else:
            polygon_coords = "No polygon coordinates available"

        # Get coordinates for the area description using PositionStack
        area_coords = get_coordinates_positionstack(area_desc, api_key)
        
        if area_coords:
            # Add a marker for the alert
            folium.Marker(
                location=area_coords,
                popup=folium.Popup(f"<b>{event}</b><br>{description}<br>Identifier: {identifier}<br>Sender: {sender}<br>Sent: {sent}", max_width=300),
                tooltip=identifier,
                icon=folium.Icon(color='blue', icon='info-sign')
            ).add_to(m)
        
        if polygon_coords and polygon_coords != "No polygon coordinates available":
            # Add a polygon to the map
            folium.Polygon(
                locations=polygon_coords[0],
                color='blue',
                fill=True,
                fill_opacity=0.4
            ).add_to(m)

    # Add a layer control
    folium.LayerControl().add_to(m)

    # Save the map to an HTML file
    m.save('alerts_map.html')
    print("Map has been created and saved as 'alerts_map.html'")

except urllib.error.HTTPError as e:
    print(f"HTTPError: {e.code} {e.reason}")
except urllib.error.URLError as e:
    print(f"URLError: {e.reason}")
except KeyError as e:
    print(f"KeyError: Missing key {e}")
# Out:
# KeyError: Missing key 'areas'

# %%
import geopandas as gpd
import folium
import mapclassify
from matplotlib import pyplot as plt

# %%
file = gpd
